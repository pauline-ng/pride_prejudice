# %%
import networkx as nx  #load networkx package

# create a graph
Graph = nx.Graph()

# add the relationships to the graph
# each person is a node, relation specifies relationship
Graph.add_edge('Mr. Bingley','Mr. Darcy',relation ='BFF’')
Graph.add_edge ("Mr. Darcy", "Lady de Bourgh", relation="aunt / nephew")
Graph.add_edge ("Lizzie Lim", "Jane Lim", relation="sisters")
Graph.add_edge ("Margaret", "Lou", relation="just married!")
Graph.add_edge ("Margaret", "Lizzie Lim", relation="cousin")
Graph.add_edge ("Margaret", "Jane Lim", relation="cousin")
Graph.add_edge ("Lou", "Mr. Bingley", relation="coworker")

pos = nx.spring_layout (Graph)

#visualize network
nx.draw (Graph, pos,  with_labels=True)
# Out:
# In /home/pauline/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/pauline/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/pauline/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/pauline/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %%
# save the network
from networkx.readwrite import json_graph
import json

# turn the graph into json format
data = json_graph.node_link_data(Graph)

# print json to the file network.json
with open('network.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

# %%
#redraw graph adding relationships
nx.draw (Graph, pos, with_labels=True)
nx.draw_networkx_edge_labels(Graph, pos, edge_labels=nx.get_edge_attributes(Graph, 'relation'))
# Out:
# {('Mr. Bingley',
#   'Mr. Darcy'): Text(-0.4901009290189985, -0.4764950376953092, 'BFF’'),
#  ('Mr. Bingley',
#   'Lou'): Text(-0.11278209950771541, -0.1368354589516823, 'coworker'),
#  ('Mr. Darcy',
#   'Lady de Bourgh'): Text(-0.8381871913180781, -0.7705595477544342, 'aunt / nephew'),
#  ('Lizzie Lim',
#   'Jane Lim'): Text(0.7223577274740205, 0.6968020770619084, 'sisters'),
#  ('Lizzie Lim',
#   'Margaret'): Text(0.5368340549513668, 0.6103677707454747, 'cousin'),
#  ('Jane Lim',
#   'Margaret'): Text(0.6427467992261997, 0.5076201656048499, 'cousin'),
#  ('Margaret',
#   'Lou'): Text(0.26774320154497816, 0.2314874854414749, 'just married!')}
